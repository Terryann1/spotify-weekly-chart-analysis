# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk

# %%
spotify=pd.read_csv('spotify_weekly_chart.csv')

# %%
spotify
# Out:
#      Pos   P+           Artist              Title  Wks   Pk   (x?)   Streams  \
# 0      1    =             SZA           Kill Bill    5    1   (x2)  47288509
# 1      2   +3    Metro Boomin            Creepin'    6    2   (x1)  30753658
# 2      3   -1       Sam Smith              Unholy   16    1   (x7)  30733283
# 3      4   -1    Harry Styles           As It Was   41    1  (x11)  28522200
# 4      5   -1    David Guetta     I'm Good (Blue)   20    2   (x4)  27260313
# ..   ...  ...              ...                ...  ...  ...    ...       ...
# 195  196  NEW  PinkPantheress        Boy's a liar    1  196    NaN   6764722
# 196  197   -8          Pritam            Kesariya   11   71    NaN   6739427
# 197  198   RE          Hozier   Take Me To Church  202    1   (x5)   6717421
# 198  199  NEW          MC K.K      Agudo Mágico 3    1  199    NaN   6713237
# 199  200   RE        Maroon 5            Payphone   50   70    NaN   6713045
#
#       Streams+       Total
# ...

# %%
spotify.describe()
# Out:
#               Pos         Wks          Pk       Streams      Streams+  \
# count  200.000000  200.000000  200.000000  2.000000e+02  1.820000e+02
# mean   100.500000   46.915000   40.395000  1.109910e+07  1.495678e+05
# std     57.879185   62.280108   43.894792  5.553110e+06  1.418367e+06
# min      1.000000    1.000000    1.000000  6.713045e+06 -3.443943e+06
# 25%     50.750000    9.750000    6.000000  7.720350e+06 -3.882400e+05
# 50%    100.500000   24.000000   23.000000  8.816404e+06  1.653155e+05
# 75%    150.250000   59.250000   64.000000  1.335638e+07  5.566680e+05
# max    200.000000  310.000000  199.000000  4.728851e+07  7.621342e+06
#
#               Total
# count  2.000000e+02
# mean   4.958258e+08
# std    6.056621e+08
# min    6.713237e+06
# 25%    1.034072e+08
# 50%    2.658862e+08
# 75%    6.465569e+08
# max    3.291327e+09

# %%
spotify['Artist'].count()
# Out:
# 200

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pos       200 non-null    int64
#  1   P+        200 non-null    object
#  2   Artist    200 non-null    object
#  3   Title     200 non-null    object
#  4   Wks       200 non-null    int64
#  5   Pk        200 non-null    int64
#  6   (x?)      36 non-null     object
#  7   Streams   200 non-null    int64
#  8   Streams+  182 non-null    float64
#  9   Total     200 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 15.8+ KB

# %%
spotify.describe()
# Out:
#               Pos         Wks          Pk       Streams      Streams+  \
# count  200.000000  200.000000  200.000000  2.000000e+02  1.820000e+02
# mean   100.500000   46.915000   40.395000  1.109910e+07  1.495678e+05
# std     57.879185   62.280108   43.894792  5.553110e+06  1.418367e+06
# min      1.000000    1.000000    1.000000  6.713045e+06 -3.443943e+06
# 25%     50.750000    9.750000    6.000000  7.720350e+06 -3.882400e+05
# 50%    100.500000   24.000000   23.000000  8.816404e+06  1.653155e+05
# 75%    150.250000   59.250000   64.000000  1.335638e+07  5.566680e+05
# max    200.000000  310.000000  199.000000  4.728851e+07  7.621342e+06
#
#               Total
# count  2.000000e+02
# mean   4.958258e+08
# std    6.056621e+08
# min    6.713237e+06
# 25%    1.034072e+08
# 50%    2.658862e+08
# 75%    6.465569e+08
# max    3.291327e+09

# %%
spotify.mean()
# Out:
# C:\Users\Terrie Ann\AppData\Local\Temp\ipykernel_13832\2211366431.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   spotify.mean()
# Pos         1.005000e+02
# Wks         4.691500e+01
# Pk          4.039500e+01
# Streams     1.109910e+07
# Streams+    1.495678e+05
# Total       4.958258e+08
# dtype: float64

# %%
spotify.mode()
# Out:
#      Pos   P+       Artist                    Title   Wks   Pk  (x?)  \
# 0      1   RE  The Weeknd                 Calm Down  12.0  1.0  (x1)
# 1      2  NaN          NaN              Die For You  36.0  NaN   NaN
# 2      3  NaN          NaN                Escapism.   NaN  NaN   NaN
# 3      4  NaN          NaN  Shut up My Moms Calling   NaN  NaN   NaN
# 4      5  NaN          NaN        Until I Found You   NaN  NaN   NaN
# ..   ...  ...          ...                      ...   ...  ...   ...
# 195  196  NaN          NaN                      NaN   NaN  NaN   NaN
# 196  197  NaN          NaN                      NaN   NaN  NaN   NaN
# 197  198  NaN          NaN                      NaN   NaN  NaN   NaN
# 198  199  NaN          NaN                      NaN   NaN  NaN   NaN
# 199  200  NaN          NaN                      NaN   NaN  NaN   NaN
#
#       Streams   Streams+       Total
# 0     6713045 -3443943.0     6713237
# 1     6713237 -2971282.0     6764722
# ...

# %%
spotify.isnull().sum()
# Out:
# Pos           0
# P+            0
# Artist        0
# Title         0
# Wks           0
# Pk            0
# (x?)        164
# Streams       0
# Streams+     18
# Total         0
# dtype: int64

# %%
pd.read_csv('spotify_weekly_chart.csv')
#spotify=spotify.fillna(method='ffill')
spotify=spotify.ffill().bfill()
spotify1=spotify.to_csv('spotify_weekly_chart1.csv')

# %%
spotify.isnull().sum()
# Out:
# Pos         0
# P+          0
# Artist      0
# Title       0
# Wks         0
# Pk          0
# (x?)        0
# Streams     0
# Streams+    0
# Total       0
# dtype: int64

# %% [markdown]
# # DATA PREPROCESSING

# %%
#Extracting independent variables
x=spotify.iloc[:,2:4].values
x
# Out:
# array([['SZA ', 'Kill Bill'],
#        ['Metro Boomin ', "Creepin'"],
#        ['Sam Smith ', 'Unholy'],
#        ['Harry Styles ', 'As It Was'],
#        ['David Guetta ', "I'm Good (Blue)"],
#        ['Manuel Turizo ', 'La Bachata'],
#        ['Taylor Swift ', 'Anti'],
#        ['Arcángel ', 'La Jumpa'],
#        ['Bizarrap ', 'Quevedo: Bzrp Music Sessions, Vol. 52'],
#        ['Stephen Sanchez ', 'Until I Found You'],
#        ['NewJeans ', 'Ditto'],
#        ['RAYE ', 'Escapism.'],
#        ['Rema ', 'Calm Down'],
#        ['JVKE ', 'golden hour'],
#        ['Tom Odell ', 'Another Love'],
#        ['Drake ', 'Rich Flex'],
#        ['OneRepublic ', "I Ain't Worried"],
#        ['Ozuna ', 'Hey Mor'],
#        ['The Weeknd ', 'Die For You'],
#        ['Meghan Trainor ', 'Made You Look'],
#        ['Central Cee ', 'LET GO'],
#        ['d4vd ', 'Here With Me'],
#        ['Bad Bunny ', 'Me Porto Bonito'],
#        ['Eminem ', 'Mockingbird'],
#        ['Miguel ', 'Sure Thing'],
# ...

# %%
#extracting dependent variables
y=spotify.iloc[:,4:10]
y
# Out:
#      Wks   Pk   (x?)   Streams   Streams+       Total
# 0      5    1   (x2)  47288509  5814143.0   208044297
# 1      6    2   (x1)  30753658  2661426.0   184223144
# 2     16    1   (x7)  30733283 -2398892.0   673533882
# 3     41    1  (x11)  28522200 -2475884.0  1747957886
# 4     20    2   (x4)  27260313 -3443943.0   568898155
# ..   ...  ...    ...       ...        ...         ...
# 195    1  196   (x1)   6764722   -20896.0     6764722
# 196   11   71   (x1)   6739427  -101231.0    84426152
# 197  202    1   (x5)   6717421  -101231.0  1058553367
# 198    1  199   (x5)   6713237  -101231.0     6713237
# 199   50   70   (x5)   6713045  -101231.0   320478893
#
# [200 rows x 6 columns]

# %% [markdown]
# # ONE HOT ENCODING

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder
#create an instance of the class
onehotencoder=OneHotEncoder()
onehotencode=onehotencoder.fit_transform(spotify['Artist'].array.reshape(-1,1))
Artist_num=pd.DataFrame(onehotencode.toarray(),columns=onehotencoder.get_feature_names_out())

# %%
Artist_num.to_csv("spotify_encoded2.csv",index=False)

# %%
from sklearn.preprocessing import OneHotEncoder
#create an instance of the class
onehotencoder=OneHotEncoder()
onehotencode=onehotencoder.fit_transform(spotify['Title'].array.reshape(-1,1))
Title_num=pd.DataFrame(onehotencode.toarray(),columns=onehotencoder.get_feature_names_out())

# %%
Title_num.to_csv("spotify_encoded1.csv",index=False)

# %%
sm=pd.read_csv("spotify_encoded1.csv")

# %%
sm.describe()
# Out:
#          x0_10:35      x0_505      x0_AMG  x0_ANTIFRAGILE  x0_About Damn Time  \
# count  200.000000  200.000000  200.000000      200.000000          200.000000
# mean     0.005000    0.005000    0.005000        0.005000            0.005000
# std      0.070711    0.070711    0.070711        0.070711            0.070711
# min      0.000000    0.000000    0.000000        0.000000            0.000000
# 25%      0.000000    0.000000    0.000000        0.000000            0.000000
# 50%      0.000000    0.000000    0.000000        0.000000            0.000000
# 75%      0.000000    0.000000    0.000000        0.000000            0.000000
# max      1.000000    1.000000    1.000000        1.000000            1.000000
#
#        x0_After Dark  x0_Agudo Mágico 3  x0_Another Love     x0_Anti  \
# count     200.000000         200.000000       200.000000  200.000000
# mean        0.005000           0.005000         0.005000    0.005000
# ...

# %%
sm=pd.read_csv("spotify_encoded2.csv")

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
#Display the shape
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (150, 2)
# (50, 2)
# (150, 6)
# (50, 6)

# %%
#specifying the split size by using test_size
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (140, 2)
# (60, 2)
# (140, 6)
# (60, 6)

# %%
#specify the random state
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # MACHINE LEARNING MODEL

# %%
#Linear regression
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
